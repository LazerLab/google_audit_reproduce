# %% [markdown]
# # Validation of handcoding sample

# %% [markdown]
# This file is to check whether the handcoding sample could contain potential results that are filtered out in the remove error step.

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import handcoding subset

# %% [markdown]
# The goal of this handcoding is to validify our decision on labeling all the results of facebook.com, twitter.com, and isntagram.com as politician-controlled contents, and youtube.com as not-politician-controlled. To do this, we decided to take a small sample from the urls that contain these domains and handcode them as whether they are politician-controlled or not. Afterwards, we calculate the percentage of politician-controlled url for each domain, which are facebook 94%, instagram 87%, twitter 99%, youtube 4%.
#
# The final labels are decided by majority agreement of 3 coders (Zhen, Allison, and Burak). The total of 943 samples and their labels can be found here: https://docs.google.com/spreadsheets/d/1g-gTuRTKIBlzfsS8Ha_xc1tJUpPEzDGOkm_mf9PlrTU/edit?gid=0#gid=0.

# %% [markdown]
# This is the subset data that I used to pull the handcoding samples for whether urls of social media domains are politician controlled. It contains all urls that have facebook.com, twitter.com, instagram.com, or youtube.com as their domains. As suggested below, only 1857 urls are there across all dates, location, and qry. 250 urls are sampled for facebook.com, twitter.com, and youtube.com. Only 193 urls have instagram.com, so all of them goes to the handcoding sample.

# %%
handcode_subset = pd.read_csv("/net/lazer/lab-lazer/shared_projects/google_audit_reproduce/intermedidate_files/merged_summary/handcode_filtered_test.csv")

# %%
handcode_subset
# Out:
#                                                     url                   qry  \
# 0                  http://www.facebook.com/LetMikeFixit           Mike Turner
# 1     https://m.facebook.com/RepBrianMast/videos/rep...            Brian Mast
# 2     https://m.facebook.com/abc3340/videos/sen-mitc...             Andy Barr
# 3     https://m.facebook.com/abc3340/videos/sen-mitc...             Andy Barr
# 4     https://m.facebook.com/captclayhiggins/videos/...          Clay Higgins
# ...                                                 ...                   ...
# 1846        https://www.youtube.com/watch?v=vqzPPbyppaw  Xochitl Torres Small
# 1847        https://www.youtube.com/watch?v=vqzPPbyppaw  Xochitl Torres Small
# 1848        https://www.youtube.com/watch?v=w3R3-9TfD6A             Raul Ruiz
# 1849        https://www.youtube.com/watch?v=wwX-SnlzHPQ          Dan Crenshaw
# 1850        https://www.youtube.com/watch?v=zOLDNfJqA1s          Adrian Smith
#
#             domain                                              title  \
# 0     facebook.com                     Mike Turner - The Computer Guy
# 1     facebook.com  Rep. Mast Fights To Stop Toxic Discharges In C...
# 2     facebook.com  Sen. Mitch McConnell joins U.S. Congressman An...
# 3     facebook.com  Sen. Mitch McConnell joins U.S. Congressman An...
# 4     facebook.com  Final bands rolling through. Wind took... - Ca...
# ...            ...                                                ...
# 1846   youtube.com          HMF LCV Rep. Xochitl Torres Small (NM-02)
# 1847   youtube.com          HMF LCV Rep. Xochitl Torres Small (NM-02)
# 1848   youtube.com  Weekly Democratic Address -- Congressman Raul ...
# 1849   youtube.com  VIRAL AD: Rep. Dan Crenshaw's Avengers-style p...
# 1850   youtube.com                                                NaN
#
#                                text  counts             path
# 0                               NaN       8     LetMikeFixit
# 1                               NaN       1     RepBrianMast
# 2                               NaN       2          abc3340
# 3                               NaN       1          abc3340
# 4                               NaN       2  captclayhiggins
# ...                             ...     ...              ...
# 1846  League of Conservation Voters     417            watch
# 1847                            NaN      16            watch
# 1848                            NaN       3            watch
# 1849                       The Hill     434            watch
# 1850                            NaN       8            watch
#
# [1851 rows x 7 columns]

# %%
len(handcode_subset[handcode_subset['domain']=='youtube.com'])
# Out:
# 193

# %% [markdown]
# ## Check whether data we filtered out later contain any social media urls.

# %% [markdown]
# Kaicheng was concerned that raw results of type 'knowledge' and 'search_related' might have been included in the above samples, because I removed the two types from the analysis after I generate the handcoding sample. But these two types of resutls do not contain any domains that we sample for the above, thus it won't matter whether we did it before or after the handcode sample generation. Here, I am going to validify that the two types of results across all raw data do not contain any social media domains.

# %% [markdown]
# First, let's import all files from the raw data, which are stored in `/net/lazer/lab-lazer/shared_projects/google_audit_reproduce/intermedidate_files/parquet_house/`

# %%
raw_data_path = '/net/lazer/lab-lazer/shared_projects/google_audit_reproduce/intermedidate_files/parquet_house/'

# %%
raw_data_files = os.listdir(raw_data_path)

# %% [markdown]
# Here's an example data file for one day.

# %%
raw_20201030 = pd.read_parquet(raw_data_path + "20201030.parquet")

# %%
raw_20201030
# Out:
#                      type  sub_rank  \
# 0                 general         0
# 1                 general         0
# 2                 general         0
# 3           twitter_cards         0
# 4           twitter_cards         1
# ...                   ...       ...
# 5004438           general         0
# 5004439  searches_related         0
# 5004440         knowledge         0
# 5004441         knowledge         1
# 5004442         knowledge         2
#
#                                                      title  \
# 0                        U.S. Representative Kathleen Rice
# 1                               Kathleen Rice for Congress
# 2                                Kathleen Rice - Wikipedia
# 3               Kathleen Rice (@RepKathleenRice) · Twitter
# 4
# ...                                                    ...
# 5004438  Duncan Hunter, former Representative for Calif...
# 5004439                                               None
# 5004440                                   Duncan D. Hunter
# 5004441                                           Profiles
# 5004442               People also search for View 10+ more
#
#                                                        url  \
# 0                          https://kathleenrice.house.gov/
# 1                            https://www.kathleenrice.com/
# 2              https://en.wikipedia.org/wiki/Kathleen_Rice
# 3        https://twitter.com/RepKathleenRice?ref_src=tw...
# 4        https://twitter.com/RepKathleenRice/status/132...
# ...                                                    ...
# 5004438  https://www.govtrack.us/congress/members/dunca...
# 5004439                                               None
# 5004440     https://en.wikipedia.org/wiki/Duncan_D._Hunter
# 5004441                                               None
# 5004442                                               None
#
#                                                       text  cmpt_rank  \
# 0                                                     None          0
# 1                                                     None          1
# 2                                                     None          2
# 3                                                     None          3
# 4        It’s been 8 years since #Sandy. The road to re...          3
# ...                                                    ...        ...
# 5004438                                               None         10
# 5004439                                               None         11
# 5004440  Duncan Duane Hunter is an American politician ...         12
# 5004441                                               None         12
# 5004442                                               None         12
#
#          serp_rank  crawl_id               qry lang  \
# 0                0  20201030     Kathleen Rice   en
# 1                1  20201030     Kathleen Rice   en
# 2                2  20201030     Kathleen Rice   en
# 3                3  20201030     Kathleen Rice   en
# 4                4  20201030     Kathleen Rice   en
# ...            ...       ...               ...  ...
# 5004438         19  20201030  Duncan D. Hunter   en
# 5004439         20  20201030  Duncan D. Hunter   en
# 5004440         21  20201030  Duncan D. Hunter   en
# 5004441         22  20201030  Duncan D. Hunter   en
# 5004442         23  20201030  Duncan D. Hunter   en
#
#                             loc_id sub_type     timestamp  \
# 0          OH-5,Ohio,United States     None          None
# 1          OH-5,Ohio,United States     None          None
# 2          OH-5,Ohio,United States     None          None
# 3          OH-5,Ohio,United States   header          None
# 4          OH-5,Ohio,United States     card  10 hours ago
# ...                            ...      ...           ...
# 5004438  KS-4,Kansas,United States     None          None
# 5004439  KS-4,Kansas,United States     None          None
# 5004440  KS-4,Kansas,United States     None          None
# 5004441  KS-4,Kansas,United States     None          None
# 5004442  KS-4,Kansas,United States     None          None
#
#                            subtitle            domain
# 0                              None         house.gov
# 1                              None  kathleenrice.com
# 2                              None     wikipedia.org
# 3                              None       twitter.com
# 4                              None       twitter.com
# ...                             ...               ...
# 5004438                        None       govtrack.us
# 5004439                        None              None
# 5004440  Former U.S. Representative     wikipedia.org
# 5004441                        None              None
# 5004442                        None              None
#
# [5004443 rows x 15 columns]

# %% [markdown]
# Then, let's filter the results type to only `knowledge` and `search_related`, which we removed later in the analysis, and check if there's any social media domain.

# %%
raw_20201030[raw_20201030['type']=='knowledge'].groupby('domain', dropna=False).size().reset_index(name='counts')
# Out:
#           domain  counts
# 0  wikipedia.org  183513
# 1            NaN  527309

# %%
raw_20201030[raw_20201030['type']=='search_related'].groupby('domain', dropna=False).size().reset_index(name='counts')
# Out:
# Empty DataFrame
# Columns: [domain, counts]
# Index: []

# %% [markdown]
# As we see in the example, there is no social media domains. Now, let's check on all files.

# %%
domain_list = []
for file in raw_data_files:
    if file == '.ipynb_checkpoints':
        continue
    raw_df = pd.read_parquet(raw_data_path + file)
    knowledge_domains = raw_df[raw_df['type']=='knowledge'].groupby('domain', dropna=False).size().reset_index(name='counts')
    search_related_domains = raw_df[raw_df['type']=='search_related'].groupby('domain', dropna=False).size().reset_index(name='counts')
    domain_list.append(knowledge_domains)
    domain_list.append(search_related_domains)
    print('processed' + file)
# Out:
# processed20201006.parquet
# processed20201229.parquet
# processed20210307.parquet
# processed20200914.parquet
# processed20210301.parquet
# processed20210306.parquet
# processed20210228.parquet
# processed20210305.parquet
# processed20210310.parquet
# processed20210317.parquet
# processed20210312.parquet
# processed20201128.parquet
# processed20210324.parquet
# processed20201221.parquet
# processed20210311.parquet
# processed20200902.parquet
# processed20210326.parquet
# processed20210321.parquet
# processed20210105.parquet
# processed20201125.parquet
# processed20210101.parquet
# processed20201021.parquet
# processed20200921.parquet
# processed20210118.parquet
# processed20210124.parquet
# processed20201031.parquet
# processed20201026.parquet
# processed20201219.parquet
# processed20201030.parquet
# processed20201212.parquet
# processed20201025.parquet
# processed20210123.parquet
# processed20210304.parquet
# processed20210115.parquet
# processed20210314.parquet
# processed20201218.parquet
# processed20201004.parquet
# processed20210309.parquet
# processed20210315.parquet
# processed20210316.parquet
# processed20201201.parquet
# processed20210216.parquet
# processed20210322.parquet
# processed20201123.parquet
# processed20210221.parquet
# processed20201109.parquet
# processed20201017.parquet
# processed20201114.parquet
# processed20201107.parquet
# processed20201112.parquet
# processed20210223.parquet
# processed20210201.parquet
# processed20201122.parquet
# processed20210122.parquet
# processed20210213.parquet
# processed20201020.parquet
# processed20210131.parquet
# processed20210111.parquet
# processed20210117.parquet
# processed20201206.parquet
# processed20201115.parquet
# processed20210219.parquet
# processed20210128.parquet
# processed20201204.parquet
# processed20201228.parquet
# processed20201207.parquet
# processed20210328.parquet
# processed20201116.parquet
# processed20210323.parquet
# processed20210125.parquet
# processed20210211.parquet
# processed20201105.parquet
# processed20210308.parquet
# processed20201227.parquet
# processed20201101.parquet
# processed20201011.parquet
# processed20201217.parquet
# processed20201209.parquet
# processed20210215.parquet
# processed20201231.parquet
# processed20201208.parquet
# processed20200920.parquet
# processed20201225.parquet
# processed20210209.parquet
# processed20201126.parquet
# processed20201111.parquet
# processed20201022.parquet
# processed20201202.parquet
# processed20210222.parquet
# processed20210331.parquet
# processed20210214.parquet
# processed20200901.parquet
# processed20201226.parquet
# processed20210204.parquet
# processed20201124.parquet
# processed20201113.parquet
# processed20210218.parquet
# processed20210320.parquet
# processed20201220.parquet
# processed20200913.parquet
# processed20201016.parquet
# processed20210114.parquet
# processed20201029.parquet
# processed20201102.parquet
# processed20210203.parquet
# processed20200903.parquet
# processed20210325.parquet
# processed20200906.parquet
# processed20210207.parquet
# processed20210217.parquet
# processed20201110.parquet
# processed20201010.parquet
# processed20200904.parquet
# processed20201121.parquet
# processed20210126.parquet
# processed20201211.parquet
# processed20201028.parquet
# processed20210121.parquet
# processed20201023.parquet
# processed20210108.parquet
# processed20210110.parquet
# processed20201018.parquet
# processed20210130.parquet
# processed20200919.parquet
# processed20210127.parquet
# processed20210113.parquet
# processed20210119.parquet
# processed20210226.parquet
# processed20201230.parquet
# processed20210106.parquet
# processed20201007.parquet
# processed20210120.parquet
# processed20210329.parquet
# processed20200930.parquet
# processed20201009.parquet
# processed20201003.parquet
# processed20210302.parquet
# processed20201222.parquet
# processed20210208.parquet
# processed20201012.parquet
# processed20201008.parquet
# processed20201205.parquet
# processed20210202.parquet
# processed20210319.parquet
# processed20201019.parquet
# processed20200915.parquet
# processed20210210.parquet
# processed20200911.parquet
# processed20201014.parquet
# processed20210205.parquet
# processed20201106.parquet
# processed20201215.parquet
# processed20201013.parquet
# processed20201015.parquet
# processed20210220.parquet
# processed20210129.parquet
# processed20210224.parquet
# processed20210107.parquet
# processed20201214.parquet
# processed20210212.parquet
# processed20200912.parquet
# processed20201001.parquet
# processed20201210.parquet
# processed20210225.parquet
# processed20201203.parquet
# processed20201118.parquet
# processed20200909.parquet
# processed20201216.parquet
# processed20201104.parquet
# processed20210109.parquet
# processed20210327.parquet
# processed20200905.parquet
# processed20210112.parquet
# processed20210318.parquet
# processed20201224.parquet
# processed20201103.parquet
# processed20201129.parquet
# processed20201120.parquet
# processed20201002.parquet
# processed20201223.parquet
# processed20201119.parquet
# processed20200910.parquet
# processed20210116.parquet
# processed20210303.parquet
# processed20210330.parquet
# processed20210227.parquet
# processed20201130.parquet
# processed20210313.parquet
# processed20200908.parquet
# processed20200929.parquet
# processed20201024.parquet
# processed20200907.parquet
# processed20201127.parquet
# processed20201213.parquet
# processed20210104.parquet
# processed20201108.parquet
# processed20201005.parquet
# processed20201027.parquet
# processed20201117.parquet
# processed20210206.parquet

# %%
all_domains = pd.concat(domain_list)

# %%
all_domains.groupby('domain', dropna=False).size().reset_index(name='counts')
# Out:
#           domain  counts
# 0                    106
# 1  wikipedia.org     200
# 2            NaN     200

# %% [markdown]
# As shown in the combined domains, there is no social media sites that could possibily sampled from the data that we later removed. Therefore, our hand-coding sample for politician-control analysis is free from potential error in this sense.
