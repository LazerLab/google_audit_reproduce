# %%
install.packages("httr")
install.packages("XML")
# Out:
# Installing package into ‘/home/aywan/R/x86_64-pc-linux-gnu-library/4.4’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/home/aywan/R/x86_64-pc-linux-gnu-library/4.4’
# (as ‘lib’ is unspecified)

# %%
library(httr)
library(XML)
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
url<-"https://en.wikipedia.org/wiki/List_of_NPR_stations"
  
# making http request 
resource<-GET(url)
parse <-htmlParse(resource)
links1<-xpathSApply(parse,path = "//a",xmlGetAttr,"href")

# %%
url<-"https://en.wikipedia.org/wiki/List_of_stations_owned_or_operated_by_Sinclair_Broadcast_Group"
  
# making http request 
resource<-GET(url)
parse <-htmlParse(resource)
links2<-xpathSApply(parse,path = "//a",xmlGetAttr,"href")

# %%
links_df <- data.frame("domain" = c(unlist(links1), unlist(links2))) %>%
filter(grepl("/wiki/", domain) == TRUE) %>%
mutate(domain = paste(tolower(gsub("/wiki/|_\\(AM\\)|_\\(FM\\)|-FM|-TV|-LD", "",domain )), ".", sep = ""))%>%
filter(nchar(domain)<6) %>% distinct()

write.csv(links_df, "/home/aywan/internal_websearch/npr_m_st.csv", row.names = F)

# %%
url<-"https://en.wikipedia.org/wiki/List_of_stations_owned_or_operated_by_Sinclair_Broadcast_Group"
  
# making http request 
resource<-GET(url)
parse <-htmlParse(resource)
links<-xpathSApply(parse,path = "//a",xmlGetAttr,"href")

# %%
links_df$domain
# Out:
#    [1] "npr."  "wbhm." "wrwa." "wjab." "wlrh." "wljs." "whil." "wvas." "wtsu."
#   [10] "wqpr." "wapr." "wual." "kket." "kska." "knba." "kmgs." "kbrw." "kyuk."
#   [19] "kbuq." "kcuk." "kdrg." "kdlg." "kuac." "kzpa." "kiyu." "kxga." "kgya."
#   [28] "khns." "klop." "kbbi." "khuu." "kigg." "krnn." "ktoo." "kxll." "kdll."
#   [37] "krbd." "kian." "kqvk." "kmxt." "kodk." "kotz." "kxkm." "ksko." "knib."
#   [46] "kuuk." "kfsk." "kznr." "kznc." "ksyu." "ksdp." "kiea." "knko." "kcaw."
#   [55] "kuhb." "ktna." "ktyu." "ktog." "knsa." "kucb." "kchu." "kstk." "kpub."
#   [64] "knau." "knag." "kuyi." "knad." "kawp." "kbaq." "kjzz." "knaq." "knaa."
#   [73] "kuas." "kuat." "kuaz." "knnb." "kawc." "kofa." "kbsa." "kuaf." "kasu."
#   [82] "klre." "kuar." "khsu." "kprx." "knhm." "knca." "kqvo." "kcho." "kvla."
#   [91] "khec." "khsr." "khsf." "kvpr." "khsg." "kxsr." "kcri." "kusc." "kerw."
#  [100] "kldd." "kpmo." "kcry." "kesc." "kmjc." "knsq." "kqei." "kcsn." "kcru."
#  [109] "kpsc." "kwca." "kzyx." "kqnc." "kfpr." "knht." "krcb." "kxjz." "kxpr."
#  [118] "knbx." "kvcr." "kpbs." "ksds." "kalw." "kqed." "kdfc." "kcbx." "kcsm."
#  [127] "kdrw." "kclu." "kclm." "kcrw." "krcg." "kazu." "kjpr." "kuop." "kxjs."
#  [136] "kkto." "kdsc." "kzyz." "knyr." "ksyc." "krza." "kajx." "kcfc." "kmpb."
#  [145] "kcjx." "kdnk." "kvov." "kepc." "krcc." "ksjd." "kpyr." "kbut." "kpru."
#  [154] "kcfr." "kuvo." "kdng." "kenc." "kvxo." "kprn." "kunc." "kvoq." "ksut."
#  [163] "kute." "kecc." "kvod." "kcse." "kcme." "kvnc." "kprh." "kvmt." "kpgs."
#  [172] "kvnf." "kcfp." "kico." "kccs." "krnc." "koto." "kjac." "kzet." "kpre."
#  [181] "kvqi." "kwcc." "wshu." "wvof." "wnpr." "wesu." "wybc." "wpkt." "whdd."
#  [190] "wqqq." "wedw." "wecs." "wrtx." "wdde." "wmph." "wamu." "weta." "wmfv."
#  [199] "wgcu." "wqcs." "wuft." "wjuf." "wjct." "wkwm." "wmko." "wfit." "wdna."
#  [208] "wlrn." "wmfe." "wucf." "wfsw." "wkgc." "wuwf." "wsmr." "wfsq." "wfsu."
#  [217] "wmnf." "wusf." "wunv." "wuga." "wabe." "wclk." "wras." "wacg." "wwio."
#  [226] "wuwg." "wngh." "wtjb." "wngu." "wppr." "wjwv." "wmum." "wrgc." "wgpb."
#  [235] "wsvh." "wfsl." "wabr." "wvvs." "wwet." "wjsp." "wxvs." "kprg." "kiph."
#  [244] "kano." "khpr." "kipo." "khph." "kjhf." "kipl." "kahu." "kipm." "kkua."
#  [253] "kbsu." "kbsx." "kibx." "kbsy." "knwo." "klgg." "kbsk." "kbsm." "kbsq."
#  [262] "krfa." "kisu." "kbyi." "kxjo." "kbss." "kwrv." "kbsw." "wsiu." "wbez."
#  [271] "wnij." "wsie." "weps." "wnie." "wvkc." "wdcb." "wbek." "wniw." "wium."
#  [280] "wbeq." "wvsi." "wglt." "wusi." "wcbu." "wipa." "wqub." "wvik." "wniu."
#  [289] "wuis." "wniq." "will." "wiuw." "wbsb." "wfiu." "wbew." "wndy." "wvpe."
#  [298] "wnin." "wboi." "wgve." "wbsh." "wfyi." "wlpr." "wbsw." "wbst." "wzjr."
#  [307] "wisu." "wvub." "wbaa." "woi."  "knsb." "knsc." "khke." "kuni." "kcck."
#  [316] "kiwr." "klcd." "klni." "knsy." "knsk." "ksui." "wsui." "knsl." "krni."
#  [325] "knsm." "kicj." "koji." "knsz." "kicw." "kicp." "kicg." "kicl." "kwit."
#  [334] "kbbg." "kznk." "kanq." "kzck." "kznz." "kanh." "kanz." "khct." "kzan."
#  [343] "kzna." "khcc." "kanu." "kanv." "krps." "khcd." "kmuw." "wkyu." "wekc."
#  [352] "wkue." "wkmt." "wekh." "wkpb." "weku." "wuky." "wfpk." "wfpl." "wuol."
#  [361] "wkmd." "wmky." "wkms." "wekp." "wdcl." "klsa." "wrkf." "kslu." "krvs."
#  [370] "kedm." "wwno." "kdaq." "ktln." "wmeh." "wbqa." "wmed." "wmep." "wmef."
#  [379] "wbqf." "wbqe." "wmea." "wmem." "wmew." "krnm." "weaa." "wypr." "wypf."
#  [388] "wfwm." "wgms." "wsdl." "wypo." "wesm." "wscl." "wtmd." "wkhs." "wnni."
#  [397] "wamh." "wfcr." "wbur." "wgbh." "wumb." "wbuh." "wzai." "wnnz." "wmvy."
#  [406] "wfpb." "wamq." "wnnu." "wcrb." "wnan." "wnck." "wnef." "wsdh." "wbsl."
#  [415] "waic." "wumg." "wbua." "wcai." "wbpr." "wicn." "wgvu." "wcml." "wuom."
#  [424] "wucx." "waus." "wdet." "wkar." "wfum." "wblu." "wvgr." "wcmw." "whbp."
#  [433] "wggl." "wiaa." "wkds." "wmuk." "wcmv." "wiab." "wlmn." "wnmu." "wcmu."
#  [442] "wcmb." "wrsx." "wcmz." "wwcm." "wica." "wblv." "wgvs." "wemu." "kncm."
#  [451] "krsu." "knse." "kbxe." "kcrb." "knbj." "kbpn." "kbpr." "wirn." "knsr."
#  [460] "ksjr." "wscn." "wdse." "wscd." "kcmf." "knwf." "wlsn." "wmls." "wtip."
#  [469] "wgpo." "kaxe." "wgrh." "kitf." "kxlc." "kmsu." "kbem." "ksjn." "know."
#  [478] "kccd." "kccm." "kcmp." "krfi." "klse." "kmse." "kzse." "krxw." "kgac."
#  [487] "knga." "kntn." "kqmn." "wirr." "krsw." "knsw." "wmah." "wmae." "wmau."
#  [496] "wmao." "wurc." "wjsu." "wmpn." "wprl." "wmaw." "wmab." "wmav." "wmsv."
#  [505] "ksms." "krcu." "krnw." "kbia." "kmuc." "kopn." "kcur." "kktr." "kwjc."
#  [514] "kxcv." "kaud." "kmst." "ksmu." "kwmu." "ksef." "kdmc." "ktbg." "ksmw."
#  [523] "kemc." "kbmc." "kglt." "kapc." "kgva." "kgpr." "kufn." "kuhm." "kyph."
#  [532] "kypx." "kukl." "kufl." "kypr." "kufm." "kpjh." "ktne." "kmne." "kcne."
#  [541] "khne." "klne." "kucv." "kzum." "krne." "kxne." "kpne." "kios." "klkr."
#  [550] "kncc." "kbsj." "kcnv." "knpr." "kwpr." "klnr." "kncj." "kunr." "kvnv."
#  [559] "ktph." "wevf." "wcnh." "wevo." "wevc." "wevh." "wevj." "wevn." "wevq."
#  [568] "wevs." "wnjz." "wwcj." "wxpj." "wbjb." "wnjm." "wnjy." "wbgo." "wqxr."
#  [577] "wrtq." "wnjp." "wnjo." "wwnj." "wnjt." "wwfm." "kanw." "kunm." "krrt."
#  [586] "kenu." "kcie." "kene." "krar." "kuut." "kusw." "kglp." "kanm." "kids."
#  [595] "krwg." "krre." "kmth." "kenw." "ktdb." "keng." "kanr." "krxg." "kbom."
#  [604] "kenm." "wamc." "wext." "wskg." "wsqx." "wxlh." "wanr." "wcwp." "wbfo."
#  [613] "wned." "wcan." "wrem." "wslu." "wrvh." "wsuc." "wsqe." "wmvq." "wcvf."
#  [622] "weos." "wslg." "wsqn." "wrcu." "wsqa." "wxxy." "wxle." "with." "wsqg."
#  [631] "wubj." "wnja." "wjff." "wxld." "wslo." "wosr." "wwes." "wfuv." "wnyc."
#  [640] "wnye." "wxlg." "wsuf." "wrfi." "woln." "wsqc." "wrvo." "wxlu." "wcel."
#  [649] "wrhv." "wrun." "wxxi." "wxxo." "wrur." "wsll." "wmht." "woxr." "wliw."
#  [658] "wrli." "wanz." "waer." "wcny." "wrvd." "wanc." "wrvn." "wuny." "wjny."
#  [667] "wrvj." "wslj." "wcqs." "wbjd." "wzpe." "wbux." "wunc." "wfae." "wsge."
#  [676] "wdav." "wncu." "wrvs." "wfss." "wfqs." "wfhe." "wkns." "wund." "wuri."
#  [685] "wyqs." "wmqs." "wteb." "wznb." "wcpe." "wrqm." "wncw." "wsif." "whqr."
#  [694] "wfdd." "wsnc." "keya." "kcnd." "kppd." "kdpr." "kdsu." "kund." "kfjm."
#  [703] "kprj." "kmpr." "kppr." "kppw." "woub." "wgbe." "wouc." "wouh." "wguc."
#  [712] "wvxu." "wclv." "wcbe." "wosu." "wose." "wdpr." "wgde." "wosa." "woul."
#  [721] "wksu." "wgle." "wcpn." "wosv." "wosb." "wnrk." "wkrj." "wmub." "wosp."
#  [730] "wksv." "wgte." "wcsu." "wkrw." "wyso." "wysu." "wouz." "koua." "kocu."
#  [739] "klcu." "kqou." "kguy." "kosn." "kccu." "kgou." "krou." "kosr." "kosu."
#  [748] "kwgs." "kwtu." "kwou." "ksmf." "ksor." "ksrg." "kmun." "koac." "kobk."
#  [757] "klbr." "koab." "kobn." "ksba." "kzby." "ketp." "klcc." "kopb." "krvm."
#  [766] "klfo." "kogl." "kagi." "kmhd." "khrv." "kojd." "klmf." "kskf." "ktvr."
#  [775] "koap." "kooz." "klco." "krbm." "klfr." "ksrs." "ktbr." "kmpq." "ksjk."
#  [784] "kotd." "ktcb." "ktmk." "kwso." "kcpb." "wdiy." "wlvr." "wypm." "wrtj."
#  [793] "wrtl." "wqln." "witf." "wrty." "wqej." "wpsx." "wvbu." "wtio." "wxph."
#  [802] "wpau." "wwpj." "whyy." "wrti." "wxpn." "wesa." "wqed." "wyep." "wvia."
#  [811] "wpsu." "wjaz." "wvya." "wrtu." "wpvd." "wnpn." "wcvy." "wnpe." "wljk."
#  [820] "wjwj." "wsci." "wltr." "whmc." "wepr." "wssb." "wnsc." "wrja." "kesd."
#  [829] "kpsd." "kqsd." "kzsd." "kdsd." "kbhe." "ktsd." "kaur." "kcsd." "krsd."
#  [838] "kysd." "kusd." "kjsd." "wutc." "wsmc." "whrs." "wknp." "wets." "wuot."
#  [847] "wkno." "wmot." "wpln." "wnxp." "wtml." "kacu." "krtp." "kacv." "kjjp."
#  [856] "kmfa." "kut."  "kvlu." "ktxp." "kamu." "keos." "ketr." "kedt." "kvut."
#  [865] "ktdh." "kera." "kkxt." "ktpd." "ktep." "kcti." "kuhf." "ktxi." "kutx."
#  [874] "kvhl." "kttz." "kldn." "kdky." "krts." "kxwt." "ktyk." "kpvu." "kojp."
#  [883] "knch." "kstx." "kpac." "kxbt." "ktot." "ktpr." "ktrl." "ktxk." "kvrt."
#  [892] "kwbu." "kmcu." "kuqu." "kueu." "kusr." "kusu." "kust." "kuxu." "kuhu."
#  [901] "kpcw." "kceu." "kusl." "kuou." "krcl." "kuer." "kusk." "wtjx." "wbtn."
#  [910] "wvba." "wvti." "wvps." "wvtx." "wvnk." "woxm." "wnch." "wvxr." "wrvt."
#  [919] "wvpa." "wvtq." "wvpr." "whrf." "wnrn." "wvtu." "wvtw." "wriq." "wmve."
#  [928] "wwvt." "wmry." "whre." "wehc." "whrl." "wwlb." "wmlu." "whrj." "whrg."
#  [937] "wemc." "wmra." "wcnv." "wchg." "wiqr." "wlur." "wmrl." "wvtr." "wvls."
#  [946] "whrx." "whro." "whrv." "wbbt." "wvru." "wcve." "wvtf." "wqiq." "wise."
#  [955] "kpbw." "kqow." "kzaz." "ksws." "knwv." "knwr." "knwu." "khnw." "klws."
#  [964] "kmws." "kpli." "komq." "kqws." "kpbg." "knwp." "kvix." "kjem." "kwsu."
#  [973] "kfae." "kexp." "kuow." "kplk." "kpbx." "kpbz." "ksfc." "knkx." "kvti."
#  [982] "ktwp." "kwws." "knwy." "kyvt." "wvby." "wvbl." "wvpw." "wvpb." "wvmr."
#  [991] "wvwv." "wvep." "wvkm." "wvpm." "wvpg." "wvds." "wvws." "wvnp." "whaa."
# [1000] "wuws." "wlbl." "whsa." "whad." "wuec." "whid." "wpne." "wojb." "whhi."
# [1009] "wgtd." "whla." "wlsu." "wern." "wha."  "whwc." "wvss." "wuwm." "wyms."
# [1018] "wrst." "whbm." "wssw." "whsf." "wxpr." "wrfw." "wshs." "whdi." "whnd."
# [1027] "kuws." "wssu." "whwa." "whrm." "wxpw." "kuwa." "kbuw." "kuwc." "kduw."
# [1036] "kuwe." "kuww." "kuwg." "kuwj." "kuwk." "kuwl." "kuwr." "kuwy." "kuwv."
# [1045] "kuwn." "kuwx." "kuwp." "kuwi." "kzuw." "kuwz." "kaiw." "kprq." "ksuw."
# [1054] "kuwd." "kuwt." "keuw." "wtto." "wabm." "wdbb." "wbma." "wear." "wpmi."
# [1063] "nbc."  "wfgx." "wjtc." "katv." "kbak." "cbs."  "krcr." "kxvu." "kcvu."
# [1072] "krvu." "kuco." "kktf." "kaef." "keca." "keuv." "kmph." "kfre." "wjla."
# [1081] "wpec." "wtvx." "wgfl." "wtwc." "wtlf." "wfxl." "wgxa." "kgan." "kfxa."
# [1090] "dabl." "kdsm." "kpth." "kbvk." "kmeg." "kboi." "kyuu." "klew." "wics."
# [1099] "wrsp." "wbui." "wsbt." "ksas." "kmtw." "wgme." "wpfo." "wbff." "wnuv."
# [1108] "wutb." "weyi." "wbsf." "wsmh." "wwmt." "wpbn." "wgtu." "wucw." "khqa."
# [1117] "ktvo." "kdnl." "wlos." "wmya." "wydo." "wcti." "wlfl." "wrdc." "wxlv."
# [1126] "wmyv." "kfxl." "khgi." "kptm." "kxvo." "ksnv." "kvcw." "krxi." "knsn."
# [1135] "wutv." "wnyo." "wham." "wuhf." "wrgb." "wcwn." "wstm." "wtvh." "wkrc."
# [1144] "wstr." "wsyx." "wtte." "wwho." "wkef." "wrgt." "wtov." "wnwo." "kokh."
# [1153] "kocb." "ktul." "kval." "kmtr." "ktvl." "kunp." "whp."  "wjac." "wwcp."
# [1162] "watm." "wpgh." "wpnt." "wolf." "wqmy." "wswb." "wjar." "wciv." "wtat."
# [1171] "wach." "wpde." "wwmb." "wtgs." "wtvc." "wfli." "wztv." "wuxp." "wnab."
# [1180] "ktxs." "ktes." "kvii." "keye." "kbtv." "kfdm." "kscc." "kdbc." "kfox."
# [1189] "kmys." "woai." "kabb." "kutv." "kmyu." "wcyb." "wemt." "wset." "wtvz."
# [1198] "wrlh." "komo." "kuns." "kima." "kepr." "wchs." "wvah." "wluk." "wcwf."
# [1207] "wmsn." "wvtv." "wgww." "wses." "kovr." "kxrm." "kxtu." "wtta." "wtxl."
# [1216] "kidk." "kxpi." "wipx." "wttv." "wdky." "wggb." "wlwc." "wlaj." "wluc."
# [1225] "kbsi." "wdka." "ksmo." "wptz." "wfff." "wnys." "wsyt." "wxbu." "whtm."
# [1234] "wgwg." "kgbt." "ketk." "wnne." "wcgv." "kbla." "wwl."  "wwwl." "wbyu."
# [1243] "wkbu." "wezb." "wrno." "wlmg." "kmez." "kczz." "krbz." "kqrc." "kcfx."
# [1252] "wdaf." "kzqz." "wil."  "wfun." "kftk." "wxos." "kpnt." "wgr."  "wben."
# [1261] "wwws." "wwkb." "wkse." "wbkv." "wroc." "wbee." "wfkl." "wbza." "weal."
# [1270] "wpaw." "wqmg." "wjmh." "kmtt." "kych." "krsk." "waaf." "wilk." "wlmz."
# [1279] "wkbp." "wkrz." "wggy." "wkrf." "woli." "word." "wyrd." "wfbc." "wspa."
# [1288] "wlts." "wshp." "wmfs." "wmle." "wrvr." "wlac." "wubt." "wnrq." "wgh."
# [1297] "wpte." "wvkl." "wwde." "wnvz." "kvi."  "knwn." "kplz." "wssp." "wmyx."
# [1306] "wxss." "khsv." "ktvn."
